# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略は、以下のステップで構築することができます。
#
# ### 1. マーケットリサーチ
# - **ターゲット市場の特定**: 誰が新製品の主要な顧客になるのかを特定します。年齢、性別、所得、地域、興味などのデモグラフィック情報を分析します。
# - **競合分析**: 競合他社の製品やマーケティング戦略を調査し、独自の価値提案を見つけます。
#
# ### 2. バリュープロポジションの定義
# - **独自性の強調**: 製品の特徴や利点を明確化し、顧客にとっての魅力を強調します。なぜこの製品を選ぶべきかを明確に伝えます。
#
# ### 3. マーケティングミックスの設計（4P）
# - **製品（Product）**: 製品の特徴、デザイン、品質について明確にします。
# - **価格（Price）**: 市場の競争状況やターゲット顧客の支払い意欲を考慮し、適切な価格を設定します。
# - **場所（Place）**: 製品を販売する場所やチャネルを決定します（オンライン、店舗など）。
# - **プロモーション（Promotion）**: 製品の認知度を高めるためのプロモーション戦略を考えます。
#
# ### 4. プロモーション戦略
# - **ローンチイベント**: 新製品発表会を開催し、メディアやインフルエンサーを招待します。製品体験を提供することで興味を引きます。
# - **デジタルマーケティング**: ソーシャルメディアキャンペーン、SEO、コンテンツマーケティングを活用してオンラインの認知度を高めます。
# - **メールマーケティング**: 事前に関心を持っている顧客を対象に、新製品に関する情報や特別オファーを配信します。
# - **インフルエンサーとのコラボレーション**: ターゲット市場に影響を与えるインフルエンサーと協力し、製品を広めてもらいます。
#
# ### 5. フィードバックと調整
# - **初期のパフォーマンスを評価**: ローンチ後の販売データや顧客フィードバックを収集し、マーケティング戦略を調整します。
# - **顧客の声を重視**: 顧客の意見に耳を傾け、必要に応じて製品やマーケティングメッセージを改善します。
#
# ### 6. 継続的な関係構築
# - **ロイヤルティプログラム**: 顧客を再度購入へと促すために、ロイヤルティプログラムを導入します。
# - **アフターサポート**: 製品購入後のサポートを充実させ、顧客満足度を向上させます。
#
# これらの戦略を統合することで、新製品を効果的に市場に投入し、強力なブランドを構築することができます。状況に応じて柔軟に対応することも重要です。

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_ca03eb65b79b4242a73afeb779ec39b2',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使うためのポイントはいくつかあります。以下に主なポイントを示します。\n\n1. **明確なプロンプト**: 言語モデルは入力されたプロンプトに基づいて応答を生成します。明確で具体的な質問や要求をすることが、より適切な回答を得るための鍵です。\n\n2. **文脈の提供**: モデルに関連する背景情報や文脈を提供することで、意図した内容の理解を助けることができます。これにより、より精度の高い応答が期待できます。\n\n3. **逐次的な対話**: モデルとの対話は、複数のステップに分けて行うと効果的です。インタラクティブなやり取りを通じて、具体的な情報を引き出すことができます。\n\n4. **アウトプットの調整**: 生成した回答に対して、満足できない場合は再度プロンプトを修正したり、追加の情報を提供したりしてみてください。柔軟にアプローチを変えることが重要です。\n\n5. **倫理的考慮**: モデルを使用する際には、倫理的な視点からも考慮が必要です。生成されたコンテンツが誤解を招いたり、不適切だったりする場合がありますので、慎重に評価することが求められます。\n\n6. **限界の理解**: 言語モデルには限界があります。特に、最新の情報や特定の専門領域においては正確性が欠けることがありますので、第三者の情報と照らし合わせることが重要です。\n\n7. **フィードバックの活用**: モデルから得られた回答を分析し、どのようなプロンプトが効果的だったかをフィードバックとして活用することで、今後のやり取りの質を向上させることができます。\n\nこれらのポイントを意識することで、言語モデルの活用がより効果的になるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1771904808,
#  'id': 'chatcmpl-DCdfkN31Sq2BG3ZTbuMgp0fNRC9V7',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=485, prompt_tokens=18, total_tokens=503, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 日本はその独自の文化、豊かな歴史、美しい自然景観、そして先進的な技術によって、多くの魅力があります。以下にいくつかのポイントを紹介します。
#
# ### 1. **文化と伝統**
# - **お祭りと行事:** 日本には多くの伝統的な祭りがあります。たとえば、田植え祭り、夏祭り、新年祝いや桜まつり
# --------------------
# もちろん、日本は多様な魅力を持った国です。以下はその一部を紹介します。
#
# 1. **美しい自然**: 日本は四季が明確で、季節ごとに異なる美しい風景があります。春の桜、夏の緑豊かな山々、秋の紅葉、冬の雪景色など、自然の移ろいを楽しむことができます。
#
# 2. **豊かな文化と歴史
# --------------------
# もちろんです！日本にはたくさんの魅力がありますね。以下にいくつかのポイントを挙げます。
#
# 1. **自然の美しさ**: 日本は四季折々の自然が楽しめます。春には桜が咲き誇り、夏は海と山の楽しみ、秋には紅葉が美しい。そして冬には雪の名所が点在します。
#
# 2. **歴史と文化**:

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
