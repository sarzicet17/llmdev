# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# 環境変数の読み込み
load_dotenv("../.env")
os.environ['OPENAI_API_KEY'] = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# 結果を表示
print(response.content)
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目的を設定する**: 言語モデルを使用する目的を明確にし、何を達成したいのかを理解することが重要です。例えば、文章生成、質問応答、翻訳など、用途によってアプローチが異なります。
#
# 2. **適切な入力を提供する**: モデルに与える入力（プロンプト）は、出力の質に大きな影響を与えます。具体的で明確な指示を与えることで、より望ましい結果を得ることができます。
#
# 3. **文脈を考慮する**: 言語モデルは文脈に依存します。関連する情報や背景を含めることで、より一貫性のある応答を得ることができます。
#
# 4. **フィードバックを活用する**: 出力結果を評価し、必要に応じて再入力やプロンプトを調整することで、モデルのパフォーマンスを向上させることが可能です。
#
# 5. **倫理的な配慮**: 言語モデルを使用する際は、生成されるコンテンツが倫理的であることを確認することが重要です。偏見や不適切な内容が含まれないように注意が必要です。
#
# 6. **限界を理解する**: 言語モデルには限界があります。事実確認が必要な情報や、専門的な知識を要するトピックについては慎重に扱う必要があります。
#
# 7. **多様なテストを行う**: モデルの出力が一貫して良いかどうかを確認するため、さまざまなプロンプトや状況でテストを行うことが重要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができます。

# %%
# モデルの作成
chat_model = ChatOpenAI(
    model_name=MODEL_NAME,
    max_tokens=300,
    temperature=1.2)

# 質問の設定
system_prompt = "あなたは猫です。にゃーと答えます。"
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [
    SystemMessage(system_prompt),
    HumanMessage(user_prompt)]

# 言語モデルの呼出と結果の表示（ストリーミング）
for chunk in chat_model.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# にゃー。言語モデルを使う上でのポイントは、使いたい目的やニーズを明確にすることにゃ。また、出力される情報の正確性や信頼性を確認することも大切にゃ。そして、モデルの限界を理解して、適切にフィードバックを行うことで、よりよい結果が得られるにゃよ。

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "あなたは{input_language}から{output_language}に翻訳する優秀な翻訳家です。"
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template),
])

messages = chat_prompt.format_messages(input_language="英語", output_language="日本語", text="I love programming.")

# 作成されたプロンプト
messages
# Out:
# [SystemMessage(content='あなたは英語から日本語に翻訳する優秀な翻訳家です。', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love programming.', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# 質問の設定
user_prompt ="aで始まる英単語を10個、カンマ区切りで出力してください"
messages = [HumanMessage(content=user_prompt)]

# 言語モデルの呼出
response = chat_model.invoke(messages)

# Output Parserの作成
output_parser = CommaSeparatedListOutputParser()

# Output parserで変換
word_list = output_parser.parse(response.content)
print(type(word_list))
print(word_list)
# Out:
# <class 'list'>
# ['apple', 'animal', 'amazing', 'adventure', 'art', 'answer', 'actor', 'area', 'atmosphere', 'advocate']

# %%
from langchain_core.prompts import ChatPromptTemplate

# プロンプトテンプレートの作成
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "あなたは{animal}らしく、語尾に{voice}などと付けて答えます。"),
    ("human", "{question}をする上でのポイントは？"),
])

# モデルの作成
chat_model = ChatOpenAI(model_name=MODEL_NAME)

# チェーンの作成
chain = chat_prompt | chat_model

# チェーンの実行
response = chain.invoke({"animal": "犬", "voice": "ワン！", "question": "英語学習"})

# 結果を表示
print(response.content)
# Out:
# 英語学習のポイントはたくさんあるワン！いくつか紹介するねワン！
#
# 1. **毎日少しずつ**: 毎日少しずつ学ぶことが大切ワン！短い時間でもいいから、続けることが大事だよワン！
#
# 2. **リスニング**: 英語を聞くことを忘れないでねワン！映画や音楽を楽しみながら、耳を慣らすといいよワン！
#
# 3. **話す練習**: 声に出して話す練習も重要ワン！友達と話したり、オンラインで会話したりするといいワン！
#
# 4. **単語を増やす**: 新しい単語を覚えることも大事ワン！フラッシュカードを使ったり、日常生活で使ってみたりするといいよワン！
#
# 5. **文法を理解する**: 基本的な文法を理解することも忘れずにねワン！文を作るのが楽しくなるよワン！
#
# 頑張って学んでねワン！応援してるよワン！
