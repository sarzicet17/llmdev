# %%
import datetime as dt
from urllib import request

def save_url_content(url):
    response = request.urlopen(url)

    html = response.read().decode("utf-8")
    
    save_text = html[:500]  # 取得したHTMLの先頭500文字を取得  
    file_name = f"{dt.datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
    with open(file_name, "w") as file:
        file.write(save_text)
    return file_name

if __name__ == "__main__":
    url = input("URLを入力してください: ")
    file_name = save_url_content(url)
    print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260220_103940.txt
