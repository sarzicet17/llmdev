# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")
os.environ['OPENAI_API_KEY']  = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# Indexの構築
documents = SimpleDirectoryReader('./data/text').load_data()
index = VectorStoreIndex.from_documents(documents)

# Chat Engineの作成
llm = OpenAI(model=MODEL_NAME)
chat_engine = index.as_chat_engine(llm=llm)

# チャットの開始
while(True):
    message = input("メッセージを入力:")
    if message.strip()=="":
        break
    display(f"質問:{message}")

    # 質問（以下にソースコードを記述）
    response = chat_engine.chat(message)        
    # 回答を表示（以下にソースコードを記述）
    print(response.response)
print("\n---ご利用ありがとうございました！---")
# Out:
# '質問:会社の勤怠に関する規定を教えて'
# 会社の勤怠に関する規定は、主に以下のような内容を含んでいます：
#
# 1. **勤務時間**: 勤務開始時間や終了時間、休憩時間などの規定。
# 2. **休暇**: 年次有給休暇、特別休暇、病気休暇などの取得方法や条件。
# 3. **遅刻・欠勤**: 遅刻や欠勤の際の連絡方法、理由の提出、罰則など。
# 4. **フレックスタイム制度**: フレックスタイム制度を導入している場合、その運用方法。
# 5. **残業**: 残業の申請方法や手当の支給基準。
#
# これらの規定は、従業員が安心して働ける環境を提供するために設けられており、関連する法令に基づいています。また、法令の改正や社会状況の変化に応じて見直されることがあります。
# '質問:休暇規則を教えて 入社以降の付与日数について'
# 休暇規則における入社以降の付与日数は、勤続年数に応じて次のようになります：
#
# - **0.5年**：10日
# - **1.5年**：11日
# - **2.5年**：12日
# - **3.5年**：14日
# - **4.5年**：16日
# - **5.5年**：18日
# - **6.5年以上**：20日
#
# 初年度には10日間の有給休暇が付与され、その後は勤続年数に応じて増加していきます。
#
# ---ご利用ありがとうございました！---
