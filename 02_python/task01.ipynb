# %%
name = "Takahiro Era"
age = 30

print("初めまして、",name,"と申します。")
print("年齢は",age,"歳です。来年は",age + 1,"歳になります。")
print("よろしくお願いします。")
# Out:
# 初めまして、 Takahiro Era と申します。
# 年齢は 30 歳です。来年は 31 歳になります。
# よろしくお願いします。
